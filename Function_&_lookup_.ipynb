# %% [markdown]
# Function & Vlookup

# %% [markdown]
# 1. Write a formula to check if the marks in cell B2 are greater than or equal to 40. If yes, return "Pass", otherwise "Fail"

# %% [markdown]
#   - =IF(B2>=40,"Pass","Fail")

# %% [markdown]
#    2. A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a formula to calculate whether the employee will get a bonus or not

# %% [markdown]
#    - =IF(AND(B2>40000, C2>=0.90), "Bonus", "No Bonus")

# %% [markdown]
#    3. Write a nested IF formula
#    if marks in B2>=90-"A">=75,-"B">=50,-Otherwise "Fail"

# %% [markdown]
#   - =IF(B2>90,"a",IF(B2>=75,"b",IF(B2>=50,"c","fail")))

# %% [markdown]
# 4. Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?

# %% [markdown]
#   - =VLOOKUP(E103,A2:B5,2,FALSE)
#
# function vlook wil used, vlook is used it searches for employee id vertically in the firtst column and returns the matching departments from another column

# %% [markdown]
#    5. If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate applicable

# %% [markdown]
#    - if the salesperson achieves sale of 40000 the determine commission rate using vlookup is =VLOOKUP(A14,A10:B14,2,"true") which give 10% commission

# %% [markdown]
#     6. The HR department maintains the following leave records of employees:onus or not .

# %% [markdown]
#    - answer has been give by me practically on google spreadsheet check here all employees leave allowance is okay
#
#   https://docs.google.com/spreadsheets/d/1-GyoQyNXI9GnkguPZquoEfdwVZNe6dGpL-iskUckro8/edit?usp=sharing

# %% [markdown]
#     7. Find the salary of EmpID = E105 using INDEX-MATCH Function.

# %% [markdown]
#   - =INDEX(B2:B5,MATCH("E105",A2:A5,0)), 72000

# %% [markdown]
#   8.  se the XLOOKUP function to find the Department of the employee with Emp ID = E303.

# %% [markdown]
#    - Department of employe with Emp ID E303
#    =XLOOKUP("E303", A2:A)5, B2:B5 USING XLOOKUP WE GET, "IT"

# %%
-
